# %% [markdown]
# #### Reprise des précédentes analyses

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

olist_df = pd.read_csv('DataSet/TrainingDataSet.csv')

# %%
olist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98344 entries, 0 to 98343
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   review_id                      98344 non-null  object
#  1   order_id                       98344 non-null  object
#  2   review_score                   98344 non-null  int64
#  3   review_comment_title           11514 non-null  object
#  4   review_comment_message         40654 non-null  object
#  5   review_creation_date           98344 non-null  object
#  6   review_answer_timestamp        98344 non-null  object
#  7   customer_id                    98344 non-null  object
#  8   order_status                   98344 non-null  object
#  9   order_purchase_timestamp       98344 non-null  object
#  10  order_approved_at              98215 non-null  object
#  11  order_delivered_carrier_date   96634 non-null  object
# ...

# %%
olist_df.head(20)
# Out:
#                            review_id                          order_id  \
# 0   fe3db7c069d694bab50cc43463f91608  2ca73e2ff9e3a186ad1e1ffb9b1d9c10
# 1   e07eee7ad7666276bd8b27fbd83fd1ff  68b3cbc68e4cd1fe19bec35f1d3bb7ee
# 2   2c5e27fc178bde7ac173c9c62c31b070  0ce9a24111d850192a933fcaab6fbad3
# 3   540e7bbb2d06cfb7f85f3a88ba7ac97f  cf73e2cb1f4a9480ed70c154da3d954a
# 4   6a18a4001ae7fd911b3b9fb13686d105  8ba3f3a9292fbc22a8b7dff752bbcd37
# 5   58044bca115705a48fe0e00a21390c54  68e55ca79d04a79f20d4bfc0146f4b66
# 6   19a52a2297e5289ab4187d238d335982  677c865b89aa97e7dbeb4bfbb50bbcfd
# 7   c92cdd7dd544a01aa35137f901669cdf  37e7875cdce5a9e5b3a692971f370151
# 8   c0f4c8301f8c29d6f53d239e194bb4c2  04db86e3493b3724ac4bd3c9a397e23c
# 9   08c9d79ec0eba1d252e3f52f14b8e6a9  e029f708df3cc108b3264558771605c6
# 10  2170c9452c2216457b36003fe2969fbb  af32671d0b8ce510a94d9111d97371d3
# 11  b193ff3c9f32a01f3a0d9ae26b94d244  e2e6ee1ed2d7f2f36b05d234983bd7a0
# ...

# %% [markdown]
# ### REVIEW_SCORE GLOBAL

# %%
plt.figure(figsize=(5, 4))
ax = sn.countplot(x='review_score', data=olist_df, palette='viridis')
ax.set_title('Distribution des notes attribuées aux commandes')
ax.set_xlabel('Note obtenue')
ax.set_ylabel('Fréquence')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18328\712411656.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sn.countplot(x='review_score', data=olist_df, palette='viridis')
# Text(0, 0.5, 'Fréquence')
